# %%
import pandas as pd
import numpy as np
import os
from itertools import chain

# %%
df = pd.read_csv(os.path.join(os.path.expanduser('./datasets'), ''))
df.columns
# Out:
# Index(['article_id', 'paragraph', 'text', 'refined_technique'], dtype='object')

# %%
def create_technique_mapping():
    """Creates a dictionary that maps original techniques to their new categories"""
    mapping = {
        'Appeal_to_Authority': 'Appeal_to_Authority',
        'Appeal_to_Fear-Prejudice': 'Appeal_to_Fear',
        'Appeal_to_Hypocrisy': 'Tu_Quoque/Whataboutism',
        'Appeal_to_Popularity': 'Appeal_to_Popularity',
        'Appeal_to_Time': 'Appeal_to_Time',
        'Appeal_to_Values': 'Appeal_to_Values/Flag_Waving',
        'Causal_Oversimplification': 'Causal_Oversimplification/Consequential_Oversimplification',
        'Consequential_Oversimplification': 'Causal_Oversimplification/Consequential_Oversimplification',
        'Conversation_Killer': 'Slogan/Conversation_Killer',
        'Doubt': 'Smear/Doubt',
        'Exaggeration-Minimisation': 'Exaggeration_Minimisation',
        'False_Dilemma-No_Choice': 'False_Dilemma_No_Choice',
        'Flag_Waving': 'Appeal_to_Values/Flag_Waving',
        'Guilt_by_Association': 'Reductio_ad_Hitlerum',
        'Loaded_Language': 'Loaded_Language',
        'Name_Calling-Labeling': 'Name_Calling',
        'Obfuscation-Vagueness-Confusion': 'Intentional_Confusion_Vagueness',
        'Questioning_the_Reputation': 'Smear/Doubt',
        'Red_Herring': 'Straw_Man/Red_Herring',
        'Repetition': 'Repetition',
        'Slogans': 'Slogan/Conversation_Killer',
        'Straw_Man': 'Straw_Man/Red_Herring',
        'Whataboutism': 'Tu_Quoque/Whataboutism',
        'no_technique_detected': 'no_technique_detected'
    }
    return mapping

# %%
def remap_techniques(df, mapping, technique_column='refined_technique'):
    """
    Remaps the techniques in the specified column according to the new schema

    Args:
        df (pd.DataFrame): DataFrame containing the technique column
        mapping (dict): Dictionary mapping old technique names to new ones
        technique_column (str): Name of the column containing techniques to be remapped

    Returns:
        pd.DataFrame: DataFrame with updated technique names
    """
    def update_techniques(techniques):
        if pd.isna(techniques):
            return 'no_technique_detected'

        # Split multiple techniques if present
        technique_list = techniques.split(',')
        # Map each technique to its new value
        updated_techniques = [mapping.get(t.strip(), t.strip()) for t in technique_list]
        # Remove duplicates while preserving order
        seen = set()
        unique_techniques = [x for x in updated_techniques if not (x in seen or seen.add(x))]
        return ','.join(unique_techniques)

    df_copy = df.copy()
    df_copy[technique_column] = df_copy[technique_column].apply(update_techniques)
    return df_copy

# %%
# Create the mapping
mapping = create_technique_mapping()

# Process the DataFrame
processed_df = remap_techniques(df, mapping)
processed_df
# Out:
#       article_id  paragraph  \
# 0              0          1
# 1              0          2
# 2              0          3
# 3              0          4
# 4              0          5
# ...          ...        ...
# 1005          69         22
# 1006          69         23
# 1007          69         24
# 1008          69         25
# 1009          69         26
#
#                                                    text  \
# 0     Verde torbido: cosa si nasconde dietro il farm...
# 1     di Roberto Graziano, Lo psicologo olandese Joo...
# 2     Sembra davvero che le ipnosi collettive e la r...
# 3     Quasi contemporaneamente a Meerloo, il Premio ...
# 4     Gli esperimenti su dissonanza cognitiva, condi...
# ...                                                 ...
# 1005  Il pompaggio di enormi quantità di CO2 nel sot...
# 1006  Non dimentichiamoci che la CO2 ha una densità ...
# 1007  Basti ricordare la liberazione improvvisa di u...
# 1008  Altri disastri, sia naturali, sia causati dall...
# 1009  Chemistry 2024, 6, 1439–1448 “Past explosive o...
#
#                                       refined_technique
# 0                           Smear/Doubt,Loaded_Language
# 1            Appeal_to_Fear,Smear/Doubt,Loaded_Language
# 2     Appeal_to_Values/Flag_Waving,Appeal_to_Fear,Na...
# 3                                 no_technique_detected
# 4                                 no_technique_detected
# ...                                                 ...
# 1005  Appeal_to_Fear,Appeal_to_Values/Flag_Waving,Ca...
# 1006     Appeal_to_Fear,Intentional_Confusion_Vagueness
# 1007                          Exaggeration_Minimisation
# 1008  Name_Calling,Smear/Doubt,Loaded_Language,Inten...
# 1009                              no_technique_detected
#
# [1010 rows x 4 columns]

# %%
all_labels = set(chain.from_iterable(label.split(',') for label in processed_df['refined_technique']))

label_to_int = {label: idx for idx,label in enumerate(sorted(all_labels))}

def encode_labels(label_str):
    return [label_to_int[label] for label in label_str.split(',')]

processed_df['encoded_labels'] = processed_df['refined_technique'].apply(encode_labels)

print(label_to_int)
# Out:
# {'Appeal_to_Authority': 0, 'Appeal_to_Fear': 1, 'Appeal_to_Popularity': 2, 'Appeal_to_Time': 3, 'Appeal_to_Values/Flag_Waving': 4, 'Causal/Consequential_Oversimplification': 5, 'Causal_Oversimplification/Consequential_Oversimplification': 6, 'Exaggeration_Minimisation': 7, 'False_Dilemma_No_Choice': 8, 'Intentional_Confusion_Vagueness': 9, 'Loaded_Language': 10, 'Name_Calling': 11, 'Reductio_ad_Hitlerum': 12, 'Repetition': 13, 'Slogan/Conversation_Killer': 14, 'Smear/Doubt': 15, 'Straw_Man/Red_Herring': 16, 'Tu_Quoque/Whataboutism': 17, 'no_technique_detected': 18}

# %%
processed_df['encoded_labels'].value_counts()
# Out:
# encoded_labels
# [18]                  350
# [15]                   69
# [7]                    19
# [10]                   19
# [6]                    18
#                      ...
# [0, 1, 3, 7]            1
# [3, 1, 7]               1
# [0, 10, 7]              1
# [7, 1, 13, 0]           1
# [11, 15, 10, 9, 7]      1
# Name: count, Length: 313, dtype: int64

# %%
processed_df = processed_df.sample(frac = 1).reset_index(drop = True)

# %%
processed_df.head()
# Out:
#    article_id  paragraph                                               text  \
# 0          63          2  Basta l’aritmetica per spiega perchè l’idea di...
# 1          69          6  Dopo essersi inventati il business della Carbo...
# 2           0        113  Costruite su una giungla inestricabile di rego...
# 3          54         17  Certo, c’è da evidenziare che buoni numeri di ...
# 4          62         17  Se utilizzassimo le loro posizioni non ci sare...
#
#                                    refined_technique            encoded_labels
# 0  Causal_Oversimplification/Consequential_Oversi...                   [6, 15]
# 1  Straw_Man/Red_Herring,Name_Calling,Smear/Doubt...       [16, 11, 15, 10, 7]
# 2  Appeal_to_Values/Flag_Waving,Appeal_to_Fear,Fa...  [4, 1, 8, 15, 10, 11, 7]
# 3                              no_technique_detected                      [18]
# 4                              no_technique_detected                      [18]

# %%
from pydpp.dpp import DPP

# %%
from sklearn.model_selection import train_test_split

# %%
df_train, df_test = train_test_split(processed_df, test_size = 0.2, random_state = 42) # We do this for sanity check

# %%
df_train = df_train.reset_index(drop = True)
df_test = df_test.reset_index(drop = True)

# %%
df_train['encoded_labels'].value_counts()
# Out:
# encoded_labels
# [18]                 282
# [15]                  58
# [15, 10]              16
# [10]                  14
# [7]                   13
#                     ...
# [1, 10, 7, 3]          1
# [8, 14, 3, 10, 7]      1
# [7, 1, 13, 0]          1
# [6, 8, 15, 10]         1
# [8, 6]                 1
# Name: count, Length: 262, dtype: int64

# %%
import torch
device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

# %%
def get_embeddings(df, model):
    sentences = df['text'].to_list()
    embeddings = model.encode(sentences)
    return embeddings

# %%
from sentence_transformers import SentenceTransformer

# %%
model = SentenceTransformer("embaas/sentence-transformers-multilingual-e5-large")

# %%
df_h = df_train[df_train['encoded_labels'].apply(lambda x: any(label in range(0, 18) for label in x))].reset_index(drop=True)
df_n_h = df_train[df_train['encoded_labels'].apply(lambda x: any(label == 18 for label in x))].reset_index(drop=True)

# %%
df_n_h
# Out:
#      article_id  paragraph                                               text  \
# 0            43         22  Ad esempio, i ghiacciai del Calderone (Gran Sa...
# 1             4          3  In questa ottava pillola su energia e clima ri...
# 2            56         15  Vorrei solo confutare un leitmotiv ricorrente ...
# 3            35          4  In breve, secondo quanto riporta il giornale e...
# 4            38         14  Infatti, una simile falsa teoria si diffuse al...
# ..          ...        ...                                                ...
# 277          59         14  Naturalmente consumo e produzione energetica n...
# 278          34          5  Noi partiamo dalle previsioni allarmanti sul “...
# 279          51         11  È stato calcolato che un solo vulcano, l’Hunga...
# 280          62         36  Ma la risposta è errata perché il corpo umano ...
# 281          62         39  Il ricercatore che analizza un sistema comples...
#
#          refined_technique encoded_labels
# 0    no_technique_detected           [18]
# 1    no_technique_detected           [18]
# 2    no_technique_detected           [18]
# 3    no_technique_detected           [18]
# 4    no_technique_detected           [18]
# ..                     ...            ...
# 277  no_technique_detected           [18]
# 278  no_technique_detected           [18]
# 279  no_technique_detected           [18]
# 280  no_technique_detected           [18]
# 281  no_technique_detected           [18]
#
# [282 rows x 5 columns]

# %%
embeds_h = get_embeddings(df_h, model)
embeddings_n_h = get_embeddings(df_n_h, model)

# %%
embeds_h.shape
# Out:
# (527, 1024)

# %%
def get_dpp_points(dpp, num_samples, df):
    
    dpp.compute_kernel(kernel_type = 'cos-sim', sigma= 0.4)
    samples_n = dpp.sample_k(num_samples) # These will return the indices 
    # Be very careful you have to use the index column not then index in itself
    df_sampled = df.iloc[samples_n]
    return df_sampled

# %%
dpp_h = DPP(embeds_h) # Call by reference
dpp_n_h = DPP(embeddings_n_h)

# %%
df_samples_h = get_dpp_points(dpp_h, num_samples = 20, df = df_h)
df_samples_n_h = get_dpp_points(dpp_n_h, num_samples = 10, df = df_n_h)

# %%
df_samples_h
# Out:
#      article_id  paragraph                                               text  \
# 14           36          5  Il motivo risiede:, • sia nel fatto che le pre...
# 42            5         18  Così, come gente che passava di qua, degli ali...
# 128          49          5  Ma voi ci credete ai politici di destra che di...
# 167           0        115  Le persone libere da militanze ideologiche e n...
# 169          67          2  La segretaria Pd prima vota e sostiene le camp...
# 171          37         13  Se le regole vengono scritte in maniera ideolo...
# 212           0         34  Le preoccupazioni sul clima in ambito UE sono ...
# 247          66         38  A proposito, le manovre per diminuire la produ...
# 258          55          8  Sono essi che ci tengono al caldo d’inverno, a...
# 275          62         38  Tale debolezza può essere superata solo con un...
# 351          62         19  Questa percentuale, che si avvicina a un dogma...
# 363          60          1  Maltempo, modifiche agli uragani e controllo d...
# 385          59          3  La colpa della confusione è dei cosiddetti tec...
# 390           0         90  Analogamente a quanto detto in precedenza, qua...
# 411          51          9  La CO2 non è il gas serra più diffuso, rappres...
# 428          65          2  L’allarme dell’Anfia: “A rischio 45 mila posti...
# 464           0        118  Le diffuse rivolte dell’anima necessarie al ca...
# 475          61          4  In realtà non c’entra niente, però alcuni grup...
# 494          57         17  Di certo non è il consumatore medio, che finis...
# 511          40         15  Essi fanno scaturire dal riscaldamento globale...
#
#                                      refined_technique  \
# 14   Straw_Man/Red_Herring,Smear/Doubt,Loaded_Language
# 42   Loaded_Language,Exaggeration_Minimisation,Smea...
# 128                                        Smear/Doubt
# 167  Appeal_to_Fear,Causal_Oversimplification/Conse...
# 169  Tu_Quoque/Whataboutism,False_Dilemma_No_Choice...
# 171  Appeal_to_Values/Flag_Waving,Causal_Oversimpli...
# 212                        Loaded_Language,Smear/Doubt
# 247  Loaded_Language,Exaggeration_Minimisation,Smea...
# 258  Loaded_Language,Exaggeration_Minimisation,Caus...
# 275                            False_Dilemma_No_Choice
# 351                           Smear/Doubt,Name_Calling
# 363                    Intentional_Confusion_Vagueness
# 385  Name_Calling,Smear/Doubt,Loaded_Language,Causa...
# 390         Smear/Doubt,Appeal_to_Fear,Loaded_Language
# 411                    Intentional_Confusion_Vagueness
# 428  Causal_Oversimplification/Consequential_Oversi...
# 464  Loaded_Language,Slogan/Conversation_Killer,Fal...
# 475                                        Smear/Doubt
# 494  Smear/Doubt,Appeal_to_Values/Flag_Waving,Loade...
# 511                    Appeal_to_Authority,Smear/Doubt
#
#                 encoded_labels
# 14                [16, 15, 10]
# 42                 [10, 7, 15]
# 128                       [15]
# 167  [1, 6, 11, 10, 7, 12, 15]
# 169            [17, 8, 15, 10]
# 171       [4, 6, 10, 7, 15, 5]
# 212                   [10, 15]
# 247             [10, 7, 15, 1]
# 258                 [10, 7, 6]
# 275                        [8]
# 351                   [15, 11]
# 363                        [9]
# 385         [11, 15, 10, 6, 7]
# 390                [15, 1, 10]
# 411                        [9]
# 428             [6, 10, 11, 1]
# 464                [10, 14, 8]
# 475                       [15]
# 494                [15, 4, 10]
# 511                    [0, 15]

# %%
df_samples_n_h
# Out:
#      article_id  paragraph                                               text  \
# 44           37         21  In soldoni, Pechino ha visto la sua produzione...
# 56           40         18  Allo stesso modo il mare si è innalzato più vo...
# 117          42          4  L’aspetto qualitativo delle curve di carico è ...
# 131          37         37  Nissan ha annunciato un drastico piano di rior...
# 141          50         60  (**) In sintesi, la CO₂ antropogenica è un fat...
# 144          60         11  In assenza di una solida ipotesi, nessuna agen...
# 146          54          7  E non sorprende, dunque, se il suo utilizzo è ...
# 206          50         26  Questo aumento è direttamente legato alle atti...
# 240          47         20  Queste proposte non intendono modificare gli o...
# 276          40          7  Un presupposto ispirato dal fatto che Arrheniu...
#
#          refined_technique encoded_labels
# 44   no_technique_detected           [18]
# 56   no_technique_detected           [18]
# 117  no_technique_detected           [18]
# 131  no_technique_detected           [18]
# 141  no_technique_detected           [18]
# 144  no_technique_detected           [18]
# 146  no_technique_detected           [18]
# 206  no_technique_detected           [18]
# 240  no_technique_detected           [18]
# 276  no_technique_detected           [18]

# %%
def generate_shots(dpp, dpp_n, num_samples, df, df_n):
    """
    Generate 'shot' lists from provided DataFrames and DPP points.
    """

    # Create the 'shot' column
    df_samples_h["shot"] = df_samples_h["text"] + ','+ df_samples_h["refined_technique"].astype(str)
    h_list = df_samples_h['shot'].to_list() #hyperpartisan shots

    df_samples_n_h["shot"] = df_samples_n_h["text"] + ','+ df_samples_n_h["refined_technique"].astype(str)
    n_h_list = df_samples_n_h['shot'].to_list() #non hyperpartisan shots

    # Convert to lists
    h_list = df_samples_h['shot'].to_list()  # hyperpartisan shots
    n_h_list = df_samples_n_h['shot'].to_list()  # non-hyperpartisan shots

    return h_list, n_h_list

# %%
h_list, n_h_list = generate_shots(dpp_h, dpp_n_h, num_samples=5, df=df_h, df_n=df_n_h) #check function generate_shots
h_list, n_h_list
# Out:
# /tmp/ipykernel_2677958/1690583121.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_samples_h["shot"] = df_samples_h["text"] + ','+ df_samples_h["refined_technique"].astype(str)
# /tmp/ipykernel_2677958/1690583121.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_samples_n_h["shot"] = df_samples_n_h["text"] + ','+ df_samples_n_h["refined_technique"].astype(str)
# (['Il motivo risiede:, • sia nel fatto che le previsioni erronee dell’IPCC provengono da un organismo delle Nazioni Unite che i decisori politici e i Media sono molto cauti nel contraddire (anche se sanno che sono discutibili); • sia nei colossali interessi economici che si sono creati attorno alla teoria dell’AGW (vedi più avanti la sezione “Il Business delle Emissioni zero”)., Oltre a questo, come spesso accade con gli atti di fede, il riscaldamento globale è entrato anche nella cultura del politicamente corretto, o cultura del piagnisteo , in cui qualcuno impedisce a qualcun altro di pensare o dire qualcosa! Di conseguenza si viene definiti negazionisti (e condannati come eretici) se:, 1.,Straw_Man/Red_Herring,Smear/Doubt,Loaded_Language',
#   'Così, come gente che passava di qua, degli alieni che hanno scoperto solo oggi il pianeta terra. Paradigmatico dell’informazione che gira oggi.,Loaded_Language,Exaggeration_Minimisation,Smear/Doubt',
#   'Ma voi ci credete ai politici di destra che dicono che sono contro la rivoluzione Green e che fanno finta di essere contro Timmermas? Io no. E vi spiego perché.,Smear/Doubt',
#   'Le persone libere da militanze ideologiche e non ancora soggette alla visione deformata di una realtà parallela, che pretende di ordinare soluzioni ridicole e verosimilmente dannose, dovrebbero chiedersi in maniera critica e costruttiva se quanto sta accadendo nella propagazione intenzionale di una emergenza climatica globale – scientificamente falsa e politicamente utile solo a pochissimi – possa essere accettabile., Il divorzio dalla realtà concreta e dal buon senso non ha mai condotto su lidi auspicabili, ma verso destini privi di una dimensione realmente umana. Ne sia testimone la storia del XX secolo.,Appeal_to_Fear,Causal_Oversimplification/Consequential_Oversimplification,Name_Calling,Loaded_Language,Exaggeration_Minimisation,Reductio_ad_Hitlerum,Smear/Doubt',
#   'La segretaria Pd prima vota e sostiene le campagne verdi dell’Ue, uccidendo il settore, poi chiede fonti per l’automotive,Tu_Quoque/Whataboutism,False_Dilemma_No_Choice,Smear/Doubt,Loaded_Language',
#   'Se le regole vengono scritte in maniera ideologica, allora sono i consumatori, le persone normali a soffrire maggiormente” il mantra di mister Toyota, che ha sempre ricordato le emissioni di anidride carbonica prodotte dalla generazione di elettricità, i costi sociali della transizione energetica oppure la perdita di milioni di posti di lavoro. Del resto Toyoda non ha sposato la causa delle auto elettriche a scatola chiusa.,Appeal_to_Values/Flag_Waving,Causal_Oversimplification/Consequential_Oversimplification,Loaded_Language,Exaggeration_Minimisation,Smear/Doubt,Causal/Consequential_Oversimplification',
#   'Le preoccupazioni sul clima in ambito UE sono talmente condivise e angoscianti da muovere Mark van Nieuwland, alto dirigente di DSM-Firmenich, ad affermare nel Settembre 2023: “Non c’è tempo da perdere per quanto concerne la riduzione delle emissioni di gas serra.,Loaded_Language,Smear/Doubt',
#   'A proposito, le manovre per diminuire la produttività dei terreni agricoli (rinaturazione, riduzione dei concimi e dei fitofarmaci, ecc.) stanno già sortendo l’effetto di obbligare molti agricoltori a cedere i loro campi alle aziende per la produzione di energia “green” che li sfrutteranno per installare pannelli fotovoltaici.,Loaded_Language,Exaggeration_Minimisation,Smear/Doubt,Appeal_to_Fear',
#   'Sono essi che ci tengono al caldo d’inverno, al fresco d’estate e sono essi che consentono di eseguire il lavoro che altrimenti dovrebbero eseguire gli schiavi., Franco Battaglia, 29 dicembre 2024 Nicolaporro.it è anche su Whatsapp.,Loaded_Language,Exaggeration_Minimisation,Causal_Oversimplification/Consequential_Oversimplification',
#   'Tale debolezza può essere superata solo con un approccio interdisciplinare-fenomenologico (Bak, 1996) che analizzi il sistema atmosfera nella sua interezza per evidenziarne una variabilità naturale, premessa necessaria per una corretta valutazione di eventuali cambiamenti climatici di natura antropica.,False_Dilemma_No_Choice',
#   'Questa percentuale, che si avvicina a un dogma di fede, è citata ovunque ma pochi sanno che é stata ottenuta da ricercatori pochi avvezzi alla statistica.,Smear/Doubt,Name_Calling',
#   'Maltempo, modifiche agli uragani e controllo del clima: si può davvero fare?,Intentional_Confusion_Vagueness',
#   'La colpa della confusione è dei cosiddetti tecnici ed esperti ai quali, quasi tutti, massimamente se ingegneri, sfugge l’essenza delle cose che usano e di cui parlano.,Name_Calling,Smear/Doubt,Loaded_Language,Causal_Oversimplification/Consequential_Oversimplification,Exaggeration_Minimisation',
#   'Analogamente a quanto detto in precedenza, quali interessi vengono garantiti e quali visioni vengono sviluppate dall’OMS (che ha scaricato sul clima impazzito addirittura l’eccesso recente di morti mondiali) e dai numerosi finanziatori e fiancheggiatori della narrazione imperante sull’emergenza climatica antropica?,Smear/Doubt,Appeal_to_Fear,Loaded_Language',
#   'La CO2 non è il gas serra più diffuso, rappresenta lo 0,04% dell’atmosfera (fonte: NOAA). Come è possibile che una varibiale cosi piccola nell’atmosfera sia cosi impattante?,Intentional_Confusion_Vagueness',
#   'L’allarme dell’Anfia: “A rischio 45 mila posti di lavoro nel nostro Paese” di Franco Lodige, Il disastro targato elettrico sta minando la tenuta del settore automotive.,Causal_Oversimplification/Consequential_Oversimplification,Loaded_Language,Name_Calling,Appeal_to_Fear',
#   'Le diffuse rivolte dell’anima necessarie al cambiamento e alla presa di coscienza sulle tante menzogne e pressioni moderne imperanti, anche climatiche, non sembrano essere ancora iniziate tra le masse ipnotizzate, ma non si dispera. Per smuoverle, tuttavia, occorre prima di tutto informarle. Basterà? Forse, no. Servono pazienza, coraggio e fiducia.,Loaded_Language,Slogan/Conversation_Killer,False_Dilemma_No_Choice',
#   'In realtà non c’entra niente, però alcuni gruppi d’interesse hanno mescolato le due cose, appunto, per i loro interessi., Come le hanno mescolate?,Smear/Doubt',
#   'Di certo non è il consumatore medio, che finisce per pagare prezzi più alti per un latte commercializzato con finalità dubbie.,Smear/Doubt,Appeal_to_Values/Flag_Waving,Loaded_Language',
#   'Essi fanno scaturire dal riscaldamento globale catastrofi climatiche, a proposito delle quali Il prof. Richard Lindzen, professore di Meteorologia al MIT e membro del National Research Council Board on Atmospheric Sciences and Climate, ha affermato: “l’IPCC sbandiera catastrofi che non potrebbero verificarsi nemmeno se i modelli fossero corretti” ., Inoltre: 1) I modelli IPCC non sono stati convalidati! E non lo potrebbero [v. Cap.4 in,Appeal_to_Authority,Smear/Doubt'],
#  ['In soldoni, Pechino ha visto la sua produzione raggiungere i livelli record di 14 milioni di tonnellate al giorno a novembre.,no_technique_detected',
#   'Allo stesso modo il mare si è innalzato più volte ma è si è anche ribassato, e lo stesso si può dire per l’aumento della temperatura terrestre.,no_technique_detected',
#   'L’aspetto qualitativo delle curve di carico è lo stesso tutti i giorni dell’anno per tutti i Paesi.,no_technique_detected',
#   'Nissan ha annunciato un drastico piano di riorganizzazione che porterà al taglio di 9 mila posti di lavoro e del 20 per cento della capacità produttiva globale.,no_technique_detected',
#   '(**) In sintesi, la CO₂ antropogenica è un fattore importante nei cambiamenti osservati nel clima della Terra e affrontare le sue emissioni è una parte centrale degli sforzi per mitigare il cambiamento climatico., Anche in questo caso ChatGPT esclude a priori qualsiasi dubbio: “Sì…”, “In sintesi, la CO₂ antropogenica è un fattore importante nei cambiamenti osservati nel clima della Terra e affrontare le sue emissioni è una parte centrale degli sforzi per mitigare il cambiamento climatico”.,no_technique_detected',
#   'In assenza di una solida ipotesi, nessuna agenzia federale sta attualmente svolgendo o pianificando ricerche sulla modifica degli uragani.,no_technique_detected',
#   'E non sorprende, dunque, se il suo utilizzo è aumentato del 100 per cento rispetto a trent’anni fa.,no_technique_detected',
#   'Questo aumento è direttamente legato alle attività umane come la combustione di combustibili fossili, la deforestazione e i cambiamenti nell’uso del suolo., 3.,no_technique_detected',
#   'Queste proposte non intendono modificare gli obiettivi di riduzione del CO2 o le ambizioni generali dell’Ue in materia climatica, ma piuttosto prendere in considerazione fattori di mercato al di fuori del controllo dei produttori, quali le tensioni commerciali, l’aumento dei costi di produzione, la lenta crescita delle infrastrutture di ricarica e la diminuzione dei sussidi all’acquisto. , Nicolaporro.it è anche su Whatsapp.,no_technique_detected',
#   'Un presupposto ispirato dal fatto che Arrhenius (1859-1927) aveva dimostrato con calcoli numerici che un aumento della CO2 può causare un aumento termico (v. Mazzarella in ).,no_technique_detected'])

# %%
h_shot = []
n_h_shot = []
for k in range(3):
    df_samples_h = get_dpp_points(dpp_h, num_samples = 5, df = df_h)
    df_samples_n_h = get_dpp_points(dpp_n_h, num_samples = 5, df = df_n_h)

    h_list, n_h_list = generate_shots(dpp_h, dpp_n_h, num_samples=5, df=df_h, df_n=df_n_h)

    h_shot.append(h_list)
    n_h_shot.append(n_h_list)

print(h_shot, n_h_shot)
# Out:
# /tmp/ipykernel_3082252/3047788375.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_samples_h["shot"] = df_samples_h["text"] + ','+ df_samples_h["label"].astype(str)
# /tmp/ipykernel_3082252/3047788375.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_samples_n_h["shot"] = df_samples_n_h["text"] + ','+ df_samples_n_h["label"].astype(str)
# /tmp/ipykernel_3082252/3047788375.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_samples_h["shot"] = df_samples_h["text"] + ','+ df_samples_h["label"].astype(str)
# /tmp/ipykernel_3082252/3047788375.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_samples_n_h["shot"] = df_samples_n_h["text"] + ','+ df_samples_n_h["label"].astype(str)
# [['Kevin McCarthy calling corona virus Chinese is a racist ploy to make a public health issue something that can be blamed on "others" - API kids in schools already being taunted about having the virus - this kind of "leadership" by Republicans is a real danger to all of us.,1', "Let me be very clear about how I believe that wearing a mask is better than taking the COVID Vaccine. First off, vaccines AREN'T full-prooff, and with these new COVID variants, we have NO IDEA how effective ALL COVID VACCINES are against the new strains at all.,1", "WSJ's @mgordonwsj reported Russian efforts to sow disinfo regarding Pfizer &amp; other vaccines 👉Read more for insights on Russia's overt information manipulation re: vaccines from a new @SecureDemocracy report by Bret Shafer and the Hamilton team https://t.co/hPFxruP4hC,1", 'we have 1.3 million vaccine doses, but only 100k have been given. Some states are lagging badly and now not sharing data QLD only gave 22% of doses they got last week, VIC just 30%. Latest federal stats only show vaccines given, not number delivered https://t.co/30k5PbKBl3 https://t.co/oUDQ5DAkmb,1', 'For all the ‘anti conspiracy’ theorists that spout anti Vaxxers - can you kindly do some research and realise the COVID ‘vaccine’ isn’t a vaccine. Vaccines are supposed to prevent you from catching a disease - this thing doesn’t....,1'], ['CONTINUED LACK OF #COVIDー19 TESTING IS A DERELICTION OF DUTY BY @realDonaldTrump. He knew since Jan about the #coronavirus.  What is particularly shameful is @POTUS is using the artificially deflated numbers due to lack of testing to say the virus has been stopped. It has not.,1', 'All "covid" vaccines will continue to cause adverse effects immediately soon after or sometime in the near future post-vaccination and in some cases kill which has already been proven to have taken place. There was no need for a vaccine/s for something not proven to exist.,1', "CDC: 1,265 DEAD and 25,212 Injuries Following Experimental COVID-19 mRNA 'Vaccines' https://t.co/ZbzWrBAuV9,1", "It's time for a proper count of the damage and death caused by the #Covid vaccines in Ontario. Officials are covering up the true toll. https://t.co/HeEEQ26ZGd,1", 'First Week of COVID Experimental Vaccines in South Korea: 7 DEAD and More than 2,800 Injured https://t.co/MdwY1qD0yd https://t.co/Yo3ycHRH4D,1'], ['Dr. Fauci is now an unofficial spokesperson of China’s COVID efforts, achievements and vaccines #DrFauci is making his priorities clear, and yet again he has disappointed many people. https://t.co/GAAXd7yEqn,1', 'Dr Mike Yeadon has signed an open letter to the European Medicines Agency questioning the safety of the Covid Vaccines... https://t.co/lMXYa4c6Bs,1', '#BREAKING: The coronavirus variant first identified in South Africa is now in Colorado, per the @CDPHE. Experts say the B.1.351 variant (also known as 501Y.V2) is more contagious and resistant to the COVID-19 vaccines currently available to the public. #COVID19Colorado https://t.co/dDJUSyigky,1', 'Read more about how the EU, UK, US and others are blocking the expansion of vaccine production at the WTO, thus prolonging the pandemic. From the WTO: https://t.co/tHLPGjC8DY Detailed Q&amp;A from Human Rights Watch: https://t.co/3vOYZT2Fae https://t.co/zNZzrT6DF6,1', 'News is that since January, classified security briefings told Trump that a pandemic was coming.  Trump did nothing, told us it was a “Democrat Hoax,” and that the fifteen cases would soon be none. Thread.  #coronavirus #TrumpPandemic #TrumpLiesPeopleDie   https://t.co/uUgpRnUZCX,1']] [['The MISD Health Services Team has been working tirelessly with the McKinney Fire Dept to administer COVID vaccines to the teachers and staff in MISD. This joint venture began back in Jan., and as of today, we have vaccinated everyone in the district who has requested a vaccine! https://t.co/nxhj6PCTNS,0', 'Sen. Rand Paul, the guy who opposed the #coronavirus relief bill and paid sick leave, tested positive on March 22  ...
# /tmp/ipykernel_3082252/3047788375.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_samples_h["shot"] = df_samples_h["text"] + ','+ df_samples_h["label"].astype(str)
# /tmp/ipykernel_3082252/3047788375.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_samples_n_h["shot"] = df_samples_n_h["text"] + ','+ df_samples_n_h["label"].astype(str)

# %%
import json

runs = {}

for k in range(3):
    # Generate the shots
    df_samples_h = get_dpp_points(dpp_h, num_samples=15, df=df_h)
    df_samples_n_h = get_dpp_points(dpp_n_h, num_samples=5, df=df_n_h)

    h_list, n_h_list = generate_shots(dpp_h, dpp_n_h, num_samples=5, df=df_h, df_n=df_n_h)

    dic_h = {f"h_shot_run_{i+1}": el for i, el in enumerate(h_list)}
    dic_n_h = {f"h_shot_run_{i+1}": el for i, el in enumerate(n_h_list)}


    runs[f"run_n_{k+1}"] = {'dic_h': dic_h, 'dic_n_h':dic_n_h}

with open(f"DPP.json", "w") as json_file:
    json.dump(runs, json_file, indent=4)
# Out:
# /tmp/ipykernel_2677958/1690583121.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_samples_h["shot"] = df_samples_h["text"] + ','+ df_samples_h["refined_technique"].astype(str)
# /tmp/ipykernel_2677958/1690583121.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_samples_n_h["shot"] = df_samples_n_h["text"] + ','+ df_samples_n_h["refined_technique"].astype(str)
# /tmp/ipykernel_2677958/1690583121.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_samples_h["shot"] = df_samples_h["text"] + ','+ df_samples_h["refined_technique"].astype(str)
# /tmp/ipykernel_2677958/1690583121.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_samples_n_h["shot"] = df_samples_n_h["text"] + ','+ df_samples_n_h["refined_technique"].astype(str)
# /tmp/ipykernel_2677958/1690583121.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_samples_h["shot"] = df_samples_h["text"] + ','+ df_samples_h["refined_technique"].astype(str)
# /tmp/ipykernel_2677958/1690583121.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_samples_n_h["shot"] = df_samples_n_h["text"] + ','+ df_samples_n_h["refined_technique"].astype(str)
